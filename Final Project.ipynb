# %%
import pandas as pd
import numpy as np
import json
print('Hello Capstone Project Course')
# Out:
# Hello Capstone Project Course

# %%
prices = pd.read_csv('pp-2020.csv')

# %%
prices
# Out:
#         {A2479555-84B1-74C7-E053-6B04A8C0887D}  266000  2020-02-13 00:00  \
# 0       {A2479555-84B2-74C7-E053-6B04A8C0887D}  315000  2020-02-14 00:00
# 1       {A2479555-84B3-74C7-E053-6B04A8C0887D}  136000  2020-03-06 00:00
# 2       {A2479555-84B4-74C7-E053-6B04A8C0887D}  155000  2020-02-28 00:00
# 3       {A2479555-84B5-74C7-E053-6B04A8C0887D}  261000  2020-02-17 00:00
# 4       {A2479555-84B6-74C7-E053-6B04A8C0887D}  405000  2020-02-21 00:00
# ...                                        ...     ...               ...
# 112454  {9DBAD221-50AC-6EB3-E053-6B04A8C0F257}  225000  2020-01-17 00:00
# 112455  {9DBAD221-50AD-6EB3-E053-6B04A8C0F257}  278000  2020-01-03 00:00
# 112456  {9DBAD221-50AF-6EB3-E053-6B04A8C0F257}  312000  2020-01-17 00:00
# 112457  {9DBAD221-50B1-6EB3-E053-6B04A8C0F257}  327000  2020-01-10 00:00
# 112458  {9DBAD221-50B2-6EB3-E053-6B04A8C0F257}  140000  2020-01-03 00:00
#
#         YO26 5TB  T  N  F   1 Unnamed: 8      MONARCH WAY        Unnamed: 10  \
# ...
